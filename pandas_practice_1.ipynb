# %%
import pandas as pd

# %%
df=pd.read_csv('movies_updated.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 3995                                   Birthday Girl      R     Comedy  2001
# 3996                                    Human Nature      R     Comedy  2001
# 3997                                            Made      R     Comedy  2001
# 3998                           One Night at McCool's      R     Comedy  2001
# 3999                                  Dr. Dolittle 2     PG     Comedy  2001
#
# ...

# %%
df1=df.groupby('genre')

# %%
df1

# %%
df1.get_group('Comedy')
# Out:
#                        name rating   genre  year  \
# 3                 Airplane!     PG  Comedy  1980
# 4                Caddyshack      R  Comedy  1980
# 17                   9 to 5     PG  Comedy  1980
# 19               Stir Crazy      R  Comedy  1980
# 26          Little Darlings      R  Comedy  1980
# ...                     ...    ...     ...   ...
# 3995          Birthday Girl      R  Comedy  2001
# 3996           Human Nature      R  Comedy  2001
# 3997                   Made      R  Comedy  2001
# 3998  One Night at McCool's      R  Comedy  2001
# 3999         Dr. Dolittle 2     PG  Comedy  2001
#
#                                released  score   votes         director  \
# 3          July 2, 1980 (United States)    7.7  221000     Jim Abrahams
# 4         July 25, 1980 (United States)    7.3  108000     Harold Ramis
# 17    December 19, 1980 (United States)    6.9   29000    Colin Higgins
# 19    December 12, 1980 (United States)    6.8   26000   Sidney Poitier
# ...

# %%
df1['genre'].value_counts()
# Out:
# genre      genre
# Action     Action        775
# Adventure  Adventure     231
# Animation  Animation     113
# Biography  Biography     175
# Comedy     Comedy       1355
# Crime      Crime         302
# Drama      Drama         807
# Family     Family          8
# Fantasy    Fantasy        33
# History    History         1
# Horror     Horror        158
# Music      Music           1
# Mystery    Mystery        13
# Romance    Romance         8
# Sci-Fi     Sci-Fi          6
# Thriller   Thriller       11
# Western    Western         3
# Name: genre, dtype: int64

# %%
df.groupby('rating').get_group('PG')
# Out:
#                                                 name rating      genre  year  \
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 8                                        Superman II     PG     Action  1980
# 10                             Any Which Way You Can     PG     Action  1980
# 11                            The Gods Must Be Crazy     PG  Adventure  1980
# ...                                              ...    ...        ...   ...
# 3962               Lagaan: Once Upon a Time in India     PG      Drama  2001
# 3963                                    The Majestic     PG      Drama  2001
# 3969                                     Cats & Dogs     PG     Action  2001
# 3980                              Millennium Actress     PG  Animation  2001
# 3999                                  Dr. Dolittle 2     PG     Comedy  2001
#
# ...

# %%
df.groupby('rating').get_group('R')
# Out:
#                        name rating      genre  year  \
# 0               The Shining      R      Drama  1980
# 1           The Blue Lagoon      R  Adventure  1980
# 4                Caddyshack      R     Comedy  1980
# 5           Friday the 13th      R     Horror  1980
# 6        The Blues Brothers      R     Action  1980
# ...                     ...    ...        ...   ...
# 3994                      O      R      Drama  2001
# 3995          Birthday Girl      R     Comedy  2001
# 3996           Human Nature      R     Comedy  2001
# 3997                   Made      R     Comedy  2001
# 3998  One Night at McCool's      R     Comedy  2001
#
#                               released  score   votes            director  \
# 0        June 13, 1980 (United States)    8.4  927000     Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8   65000      Randal Kleiser
# 4        July 25, 1980 (United States)    7.3  108000        Harold Ramis
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.groupby(['rating','year']).get_group(('R','2001'))
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:817, in BaseGroupBy.get_group(self, name, obj)
#     815 inds = self._get_index(name)
#     816 if not len(inds):
# --> 817     raise KeyError(name)
#     819 return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: ('R', '2001')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 3995                                   Birthday Girl      R     Comedy  2001
# 3996                                    Human Nature      R     Comedy  2001
# 3997                                            Made      R     Comedy  2001
# 3998                           One Night at McCool's      R     Comedy  2001
# 3999                                  Dr. Dolittle 2     PG     Comedy  2001
#
# ...

# %%
df[(df['rating']=='PG')&(df['year']=='1980')]
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime,,]
# Index: []

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 3995                                   Birthday Girl      R     Comedy  2001
# 3996                                    Human Nature      R     Comedy  2001
# 3997                                            Made      R     Comedy  2001
# 3998                           One Night at McCool's      R     Comedy  2001
# 3999                                  Dr. Dolittle 2     PG     Comedy  2001
#
# ...
